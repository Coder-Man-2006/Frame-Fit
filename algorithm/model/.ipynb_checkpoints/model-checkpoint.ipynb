# %%
import pandas as pd
import numpy as np
# import sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("measurements.csv")
df
# Out:
#      Length of Face  Temple to Temple  Cheekbone to Cheekbone    Jawline  \
# 0         11.914923          8.504296                6.969192  18.246684
# 1         12.104159          8.506379                7.069777  18.623188
# 2         12.214310          8.465597                7.062593  18.633956
# 3         12.412841          8.543487                7.067753  18.634794
# 4         12.300000          8.464279                6.969192  18.527837
# ..              ...               ...                     ...        ...
# 350       15.012850         10.545431                8.583791  23.498490
# 351       15.053524         10.464756                8.378979  23.418908
# 352       15.185255         10.556451                8.523818  23.521679
# 353       15.088137         10.548600                8.483454  23.267224
# 354       15.005289         10.456566                8.478772  23.355752
#
#              Time
# 0    1.693141e+09
# 1    1.693141e+09
# 2    1.693141e+09
# ...
